# %% [markdown]
# <a href="https://colab.research.google.com/github/thivistan/NEUROSEGMENT-ADVANCING-BRAIN-TUMOR-SEGMENTATION-WITH-ENHANCED-U-NET-ARCHITECTURES/blob/main/Image_Segementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Step 1 - Set up environment**

# %%
import nibabel as nib
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from skimage.transform import rotate
from skimage.util import montage
import os
from sklearn.model_selection import train_test_split
import keras
import cv2
import tensorflow
import random
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import numpy as np
from keras.callbacks import CSVLogger
import keras.backend as K
import zipfile
import pandas as pd

# %%
# !pip install -r requirements.txt
# Out:
# Collecting nibabel==5.1.0 (from -r requirements.txt (line 1))
#   Downloading nibabel-5.1.0-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 27.3 MB/s eta 0:00:00
# Collecting matplotlib==3.5.1 (from -r requirements.txt (line 2))
#   Downloading matplotlib-3.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 71.2 MB/s eta 0:00:00
# Collecting scikit-image==0.20.0 (from -r requirements.txt (line 3))
#   Downloading scikit_image-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 56.2 MB/s eta 0:00:00
# Collecting scikit-learn==1.0.2 (from -r requirements.txt (line 4))
#   Downloading scikit_learn-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 32.2 MB/s eta 0:00:00
# Collecting opencv-python==4.7.0.68 (from -r requirements.txt (line 5))
#   Downloading opencv_python-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 9.9 MB/s eta 0:00:00
# Collecting tensorflow==2.8.4 (from -r requirements.txt (line 6))
#   Downloading tensorflow-2.8.4-cp310-cp310-manylinux2010_x86_64.whl (498.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 MB 3.1 MB/s eta 0:00:00
# Collecting keras==2.8.0 (from -r requirements.txt (line 7))
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 49.6 MB/s eta 0:00:00
# Collecting kaggle==1.5.13 (from -r requirements.txt (line 8))
#   Downloading kaggle-1.5.13.tar.gz (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pandas==1.4.2 (from -r requirements.txt (line 9))
#   Downloading pandas-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 78.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from nibabel==5.1.0->-r requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: packaging>=17 in /usr/local/lib/python3.10/dist-packages (from nibabel==5.1.0->-r requirements.txt (line 1)) (24.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.1->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.20.0->-r requirements.txt (line 3)) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.20.0->-r requirements.txt (line 3)) (3.3)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.20.0->-r requirements.txt (line 3)) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.20.0->-r requirements.txt (line 3)) (2024.4.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.20.0->-r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.20.0->-r requirements.txt (line 3)) (0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0.2->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0.2->-r requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (3.9.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (3.3.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 91.0 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.9,>=2.8 (from tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 kB 39.9 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4->-r requirements.txt (line 6)) (1.62.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.13->-r requirements.txt (line 8)) (2024.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.13->-r requirements.txt (line 8)) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.13->-r requirements.txt (line 8)) (4.66.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.13->-r requirements.txt (line 8)) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.13->-r requirements.txt (line 8)) (2.0.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.2->-r requirements.txt (line 9)) (2023.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8.4->-r requirements.txt (line 6)) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (2.27.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (3.6)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 87.9 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6))
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 47.3 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle==1.5.13->-r requirements.txt (line 8)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle==1.5.13->-r requirements.txt (line 8)) (3.7)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle==1.5.13->-r requirements.txt (line 8)) (1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.4->-r requirements.txt (line 6)) (3.2.2)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.13-py3-none-any.whl size=77713 sha256=94ca783b7a2dd72e5cdb2f66e04635e58adb0f0d0c9fb6e6e3f0f2772091c31f
#   Stored in directory: /root/.cache/pip/wheels/f3/16/ff/34e7d368370d4fd68bb749a59f1d2639ed66f3c14358e340a1
# Successfully built kaggle
# Installing collected packages: tensorflow-estimator, tensorboard-plugin-wit, keras, tensorboard-data-server, protobuf, opencv-python, nibabel, keras-preprocessing, scikit-learn, scikit-image, pandas, matplotlib, kaggle, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.15.0
#     Uninstalling tensorflow-estimator-2.15.0:
#       Successfully uninstalled tensorflow-estimator-2.15.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: nibabel
#     Found existing installation: nibabel 4.0.2
#     Uninstalling nibabel-4.0.2:
#       Successfully uninstalled nibabel-4.0.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.16
#     Uninstalling kaggle-1.5.16:
#       Successfully uninstalled kaggle-1.5.16
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.0
#     Uninstalling google-auth-oauthlib-1.2.0:
#       Successfully uninstalled google-auth-oauthlib-1.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.2.0 requires matplotlib>=3.7.1, but you have matplotlib 3.5.1 which is incompatible.
# bigframes 1.2.0 requires pandas>=1.5.0, but you have pandas 1.4.2 which is incompatible.
# bigframes 1.2.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.0.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 1.4.2 which is incompatible.
# pandas-gbq 0.19.2 requires google-auth-oauthlib>=0.7.0, but you have google-auth-oauthlib 0.4.6 which is incompatible.
# plotnine 0.12.4 requires matplotlib>=3.6.0, but you have matplotlib 3.5.1 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you have pandas 1.4.2 which is incompatible.
# tensorflow-datasets 4.9.4 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.8.4 which is incompatible.
# Successfully installed google-auth-oauthlib-0.4.6 kaggle-1.5.13 keras-2.8.0 keras-preprocessing-1.1.2 matplotlib-3.5.1 nibabel-5.1.0 opencv-python-4.7.0.68 pandas-1.4.2 protobuf-3.19.6 scikit-image-0.20.0 scikit-learn-1.0.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.4 tensorflow-estimator-2.8.0

# %% [markdown]
# **Step 2 - Fetching the Dataset**

# %%
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle config set -n apikey -v ~/.kaggle/kaggle.json
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# - apikey is now set to: /root/.kaggle/kaggle.json

# %% [markdown]
# **Step 3 - Downloading the Dataset**

# %%
# !kaggle datasets download -d awsaf49/brats20-dataset-training-validation
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading brats20-dataset-training-validation.zip to /content
# 100% 4.16G/4.16G [03:08<00:00, 26.4MB/s]
# 100% 4.16G/4.16G [03:08<00:00, 23.7MB/s]

# %%
# !ls
# Out:
# brats20-dataset-training-validation.zip  drive	sample_data

# %% [markdown]
# **Step 4 - Unzipping the Dataset**

# %%
import zipfile

path_to_zip_file = "brats20-dataset-training-validation.zip"
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall("brats20-dataset-training-validation")

# %%
import os

# Absolute path of the incorrectly named file
old_name = "brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_355/W39_1998.09.19_Segm.nii"
new_name = "brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_355/BraTS20_Training_355_seg.nii"

# Renaming the file
try:
    os.rename(old_name, new_name)
    print("The file has been successfully renamed")
except FileNotFoundError:
    print("Maybe you have already renamed the file or the file does not exist.")
# Out:
# The file has been successfully renamed

# %% [markdown]
# **Step 5 - Data Exploration**

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Specify a sample path (here we will take the first patient of the Training dataset)
sample_path = 'brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_'

# Load the 4 MRI modalities and the segmentation located in the patient's path using the nibabel library
t1_img = nib.load(sample_path + 't1.nii')
t1ce_img = nib.load(sample_path + 't1ce.nii')
t2_img = nib.load(sample_path + 't2.nii')
flair_img = nib.load(sample_path + 'flair.nii')
seg_img = nib.load(sample_path + 'seg.nii')

# Get the image data
t1_data = t1_img.get_fdata()
t1ce_data = t1ce_img.get_fdata()
t2_data = t2_img.get_fdata()
flair_data = flair_img.get_fdata()
seg_data = seg_img.get_fdata()

# Plot the 100th slice of the 4 MRI modalities and the segmentation
slice_nb = 100

fig, axs = plt.subplots(1, 5, figsize=(20, 20))
axs[0].imshow(t1_data[:, :, slice_nb], cmap="gray")
axs[0].set_title('T1')
axs[1].imshow(t1ce_data[:, :, slice_nb], cmap="gray")
axs[1].set_title('T1CE')
axs[2].imshow(t2_data[:, :, slice_nb], cmap="gray")
axs[2].set_title('T2')
axs[3].imshow(flair_data[:, :, slice_nb], cmap="gray")
axs[3].set_title('FLAIR')
axs[4].imshow(seg_data[:, :, slice_nb], cmap="gray")
axs[4].set_title('Segmentation')
plt.show()

# %%
# Modality shape
print(t1_data.shape)

# Segmentation shape
print(seg_data.shape)
# Out:
# (240, 240, 155)
# (240, 240, 155)

# %%
import matplotlib.pyplot as plt
import scipy.ndimage as ndimage

# Assuming 't1_data' is already loaded and contains the MRI data

# Plot a MRI modality through all planes
slice_nb = 100

fig, axs2 = plt.subplots(1, 3, figsize=(10, 10))

# Apply a 90° rotation with an automatic resizing, otherwise the display is less obvious to analyze
axs2[0].imshow(ndimage.rotate(t1_data[slice_nb, :, :], 90, reshape=True), cmap="gray")
axs2[0].set_title('T1 - Sagittal View')

axs2[1].imshow(ndimage.rotate(t1_data[:, slice_nb, :], 90, reshape=True), cmap="gray")
axs2[1].set_title('T1 - Coronal View')

axs2[2].imshow(t1_data[:, :, slice_nb], cmap="gray")
axs2[2].set_title('T1 - Axial View')

plt.show()

# %%
# Display all slices of a segmentation
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(seg_data[:,:,:]), 90, resize=True), cmap ='gray')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(t1_data[60:135,:,:]), 90, resize=True), cmap ='gray')

# %% [markdown]
# **Step 6 - Plot Segmenation**

# %%
# Plot a segmantation
some_seg_img = nib.load("brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_seg.nii").get_fdata()

cmap = mpl.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = mpl.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

plt.imshow(some_seg_img[100,:,:], cmap=cmap, norm=norm)
plt.colorbar()

# %%
data_path = "brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData"
seg_samples = [os.path.join(data_path, sample, f"{sample}_seg.nii") for sample in os.listdir(data_path) if not sample.endswith('.csv')]

saved_values = []
max_nb_values = 0
for sample in seg_samples:
    seg_img = nib.load(sample).get_fdata()
    unique_values = np.unique(seg_img)
    nb_unique_values = len(np.unique(seg_img))

    if nb_unique_values > max_nb_values:
        max_nb_values = nb_unique_values
        saved_values = unique_values

print(f"Maximum number of values in all segmentation images: {max_nb_values}")
print(f"Values: {saved_values}")
# Out:
# Maximum number of values in all segmentation images: 4
# Values: [0. 1. 2. 4.]

# %%
values, counts = np.unique(some_seg_img, return_counts=True)
print(counts)
# Out:
# [8716021   15443  168794   27742]

# %%
# Deletion of class 0
seg_0 = some_seg_img.copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = some_seg_img.copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = some_seg_img.copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_3 = some_seg_img.copy()
seg_3[seg_3 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 3']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, axs3 = plt.subplots(1, 5, figsize=(15, 15))

axs3[0].imshow(some_seg_img[100,:,:], cmap=cmap, norm=norm)
axs3[0].set_title('Original Segmentation')
axs3[0].legend(handles=legend, loc='upper right')

axs3[1].imshow(seg_0[100,:,:], cmap=cmap, norm=norm)
axs3[1].set_title('Not Tumor class 0')

axs3[2].imshow(seg_1[100,:,:], cmap=cmap, norm=norm)
axs3[2].set_title('Non-Enhancing Tumor class 1')

axs3[3].imshow(seg_2[100,:,:], cmap=cmap, norm=norm)
axs3[3].set_title('Edema class 2')

axs3[4].imshow(seg_3[100,:,:], cmap=cmap, norm=norm)
axs3[4].set_title('Enhancing Tumor class 3')

plt.show()

# %%
# Define selected slices range
VOLUME_START_AT = 60
VOLUME_SLICES = 75

# %% [markdown]
# **Step 7 - Training the Data**

# %%
# Specify path of our BraTS2020 directory
data_path = "brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData"

# Retrieve all samples from path with listdir(). This method lists of all files + directories in the specified directory.
samples = os.listdir(data_path)
print("Number of samples:", len(samples))
# Out:
# Number of samples: 371

# %%
samples.remove("survival_info.csv")
samples.remove("name_mapping.csv")

# %%
  # Split the dataset into train and validation sets
  samples_train, samples_val = train_test_split(samples, test_size=0.2, random_state=42)

  # Split the train set into the real train set and in a test set
  samples_train, samples_test = train_test_split(samples_train, test_size=0.15, random_state=42)

  # Print data distribution (Train: 68%, Test: 12%, Val: 20%)
  print(f"Train length: {len(samples_train)}")
  print(f"Validation length: {len(samples_val)}")
  print(f"Test length: {len(samples_test)}")
# Out:
# Train length: 250
# Validation length: 74
# Test length: 45

# %% [markdown]
# **Step 8 - Data Generator Function**

# %%
# DataGenerator from Rastislav's notebook, https://www.kaggle.com/code/rastislav/3d-mri-brain-tumor-segmentation-u-net
import os
import tensorflow

# Constants like `VOLUME_SLICES` and `VOLUME_START_AT` need to be defined
# For example:
VOLUME_SLICES = 64  # Placeholder value, set this to the number of slices you want to use
VOLUME_START_AT = 30  # Placeholder value, set this to the slice index you want to start at

IMG_SIZE = 128

class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, data_path, batch_size=1, n_channels=2, shuffle=True):
        'Initialization'
        self.dim = (IMG_SIZE, IMG_SIZE)  # Resized image dimensions (128 x 128)
        self.batch_size = batch_size  # Number of images to load each time
        self.list_IDs = list_IDs  # Patients IDs
        self.data_path = data_path  # Base path to the data
        self.n_channels = n_channels  # Number of channels (T1CE + FLAIR)
        self.shuffle = shuffle  # Indicates if data is shuffled for each epoch
        self.on_epoch_end()  # Updates indexes after each epoch

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Load & Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))

        # Generate data
        for c, i in enumerate(Batch_ids):

            # Get path of each RMI modality and the segmentation
            sample_path = os.path.join(data_path, i, i)
            t1ce_path = sample_path + '_t1ce.nii'
            flair_path = sample_path + '_flair.nii'
            seg_path = sample_path + '_seg.nii'
            #t1_path = sample_path + '_t1.nii'
            #t2_path = sample_path + '_t2.nii'

            # Extract the data from these paths
            t1ce = nib.load(t1ce_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()
            #t1 = nib.load(t1_paths).get_fdata()
            #t2 = nib.load(t2_path).get_fdata()

            for j in range(VOLUME_SLICES):
                 X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                 X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

                 y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT]

        # Masks / Segmentations
        y[y==4] = 3
        mask = tensorflow.one_hot(y, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))

        # Scale data between 0 and 1 (since the minimum value in the data is 0)
        return X/np.max(X), Y

# %%
data_path = "brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData"

# Make sure samples_train, samples_val, and samples_test are defined before this point
training_generator = DataGenerator(samples_train, data_path)
valid_generator = DataGenerator(samples_val, data_path)
test_generator = DataGenerator(samples_test, data_path)

# %% [markdown]
# **Step 9 - Building the U-Net model**

# %%
# U-Net implementation for BraTS 2019 by Naomi Fridman, https://naomi-fridman.medium.com/multi-class-image-segmentation-a5cc671e647a
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)

    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, 1, activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

# %%
# Compute metric between the predicted segmentation and the ground truth
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
# Define input data shape
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

# Build and compile the model
model = build_unet(input_layer, 'he_normal', 0.2)

model.compile(loss="categorical_crossentropy", optimizer=tensorflow.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tensorflow.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity] )

# %%
callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=2, min_lr=0.000001, verbose=1),

    keras.callbacks.ModelCheckpoint(filepath = 'model_.{epoch:02d}-{val_loss:.6f}.m5',
                             verbose=1, save_best_only=True, save_weights_only = True),

    CSVLogger('training.log', separator=',', append=False)
]

# %% [markdown]
# **Step 10 - Model Training**

# %%
model.fit(training_generator,
          epochs=35,
          steps_per_epoch=len(samples_train),
          callbacks=callbacks,
          validation_data=valid_generator)
# Out:
# Epoch 1/35
# 250/250 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9777 - mean_io_u: 0.6249 - dice_coef: 0.2631 - precision: 0.9761 - sensitivity: 0.9653 - specificity: 0.9936
# Epoch 1: val_loss improved from inf to 0.07975, saving model to model_.01-0.079752.m5
# 250/250 [==============================] - 160s 527ms/step - loss: 0.1370 - accuracy: 0.9777 - mean_io_u: 0.6249 - dice_coef: 0.2631 - precision: 0.9761 - sensitivity: 0.9653 - specificity: 0.9936 - val_loss: 0.0798 - val_accuracy: 0.9809 - val_mean_io_u: 0.5017 - val_dice_coef: 0.2736 - val_precision: 0.9806 - val_sensitivity: 0.9807 - val_specificity: 0.9936 - lr: 0.0010
# Epoch 2/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9807 - mean_io_u: 0.5726 - dice_coef: 0.2788 - precision: 0.9808 - sensitivity: 0.9799 - specificity: 0.9936
# Epoch 2: val_loss improved from 0.07975 to 0.07432, saving model to model_.02-0.074324.m5
# 250/250 [==============================] - 122s 488ms/step - loss: 0.0828 - accuracy: 0.9807 - mean_io_u: 0.5726 - dice_coef: 0.2788 - precision: 0.9808 - sensitivity: 0.9799 - specificity: 0.9936 - val_loss: 0.0743 - val_accuracy: 0.9809 - val_mean_io_u: 0.7897 - val_dice_coef: 0.2858 - val_precision: 0.9806 - val_sensitivity: 0.9806 - val_specificity: 0.9936 - lr: 0.0010
# Epoch 3/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9807 - mean_io_u: 0.4831 - dice_coef: 0.2897 - precision: 0.9818 - sensitivity: 0.9793 - specificity: 0.9940
# Epoch 3: val_loss did not improve from 0.07432
# 250/250 [==============================] - 122s 487ms/step - loss: 0.0787 - accuracy: 0.9807 - mean_io_u: 0.4831 - dice_coef: 0.2897 - precision: 0.9818 - sensitivity: 0.9793 - specificity: 0.9940 - val_loss: 0.0753 - val_accuracy: 0.9810 - val_mean_io_u: 0.4031 - val_dice_coef: 0.2906 - val_precision: 0.9857 - val_sensitivity: 0.9766 - val_specificity: 0.9952 - lr: 0.0010
# Epoch 4/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9807 - mean_io_u: 0.4286 - dice_coef: 0.2849 - precision: 0.9813 - sensitivity: 0.9797 - specificity: 0.9938
# Epoch 4: val_loss improved from 0.07432 to 0.06899, saving model to model_.04-0.068992.m5
# 250/250 [==============================] - 122s 488ms/step - loss: 0.0785 - accuracy: 0.9807 - mean_io_u: 0.4286 - dice_coef: 0.2849 - precision: 0.9813 - sensitivity: 0.9797 - specificity: 0.9938 - val_loss: 0.0690 - val_accuracy: 0.9809 - val_mean_io_u: 0.4103 - val_dice_coef: 0.2937 - val_precision: 0.9806 - val_sensitivity: 0.9806 - val_specificity: 0.9936 - lr: 0.0010
# Epoch 5/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9810 - mean_io_u: 0.4223 - dice_coef: 0.3095 - precision: 0.9824 - sensitivity: 0.9795 - specificity: 0.9941
# Epoch 5: val_loss improved from 0.06899 to 0.06094, saving model to model_.05-0.060938.m5
# 250/250 [==============================] - 122s 488ms/step - loss: 0.0699 - accuracy: 0.9810 - mean_io_u: 0.4223 - dice_coef: 0.3095 - precision: 0.9824 - sensitivity: 0.9795 - specificity: 0.9941 - val_loss: 0.0609 - val_accuracy: 0.9823 - val_mean_io_u: 0.4295 - val_dice_coef: 0.3396 - val_precision: 0.9863 - val_sensitivity: 0.9787 - val_specificity: 0.9954 - lr: 0.0010
# Epoch 6/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9806 - mean_io_u: 0.4109 - dice_coef: 0.3085 - precision: 0.9824 - sensitivity: 0.9786 - specificity: 0.9941
# Epoch 6: val_loss did not improve from 0.06094
# 250/250 [==============================] - 121s 483ms/step - loss: 0.0705 - accuracy: 0.9806 - mean_io_u: 0.4109 - dice_coef: 0.3085 - precision: 0.9824 - sensitivity: 0.9786 - specificity: 0.9941 - val_loss: 0.0671 - val_accuracy: 0.9811 - val_mean_io_u: 0.4105 - val_dice_coef: 0.3152 - val_precision: 0.9824 - val_sensitivity: 0.9806 - val_specificity: 0.9941 - lr: 0.0010
# Epoch 7/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9814 - mean_io_u: 0.4089 - dice_coef: 0.3323 - precision: 0.9847 - sensitivity: 0.9790 - specificity: 0.9949
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 7: val_loss did not improve from 0.06094
# 250/250 [==============================] - 120s 481ms/step - loss: 0.0649 - accuracy: 0.9814 - mean_io_u: 0.4089 - dice_coef: 0.3323 - precision: 0.9847 - sensitivity: 0.9790 - specificity: 0.9949 - val_loss: 0.0649 - val_accuracy: 0.9803 - val_mean_io_u: 0.3757 - val_dice_coef: 0.3479 - val_precision: 0.9885 - val_sensitivity: 0.9732 - val_specificity: 0.9961 - lr: 0.0010
# Epoch 8/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9835 - mean_io_u: 0.3799 - dice_coef: 0.3838 - precision: 0.9893 - sensitivity: 0.9789 - specificity: 0.9963
# Epoch 8: val_loss improved from 0.06094 to 0.05233, saving model to model_.08-0.052326.m5
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0517 - accuracy: 0.9835 - mean_io_u: 0.3799 - dice_coef: 0.3838 - precision: 0.9893 - sensitivity: 0.9789 - specificity: 0.9963 - val_loss: 0.0523 - val_accuracy: 0.9835 - val_mean_io_u: 0.3828 - val_dice_coef: 0.3883 - val_precision: 0.9902 - val_sensitivity: 0.9749 - val_specificity: 0.9966 - lr: 2.0000e-04
# Epoch 9/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9858 - mean_io_u: 0.3857 - dice_coef: 0.4186 - precision: 0.9905 - sensitivity: 0.9808 - specificity: 0.9967
# Epoch 9: val_loss improved from 0.05233 to 0.04186, saving model to model_.09-0.041858.m5
# 250/250 [==============================] - 122s 487ms/step - loss: 0.0440 - accuracy: 0.9858 - mean_io_u: 0.3857 - dice_coef: 0.4186 - precision: 0.9905 - sensitivity: 0.9808 - specificity: 0.9967 - val_loss: 0.0419 - val_accuracy: 0.9861 - val_mean_io_u: 0.3930 - val_dice_coef: 0.4361 - val_precision: 0.9920 - val_sensitivity: 0.9801 - val_specificity: 0.9972 - lr: 2.0000e-04
# Epoch 10/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9868 - mean_io_u: 0.3963 - dice_coef: 0.4444 - precision: 0.9905 - sensitivity: 0.9829 - specificity: 0.9967
# Epoch 10: val_loss improved from 0.04186 to 0.04050, saving model to model_.10-0.040502.m5
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0397 - accuracy: 0.9868 - mean_io_u: 0.3963 - dice_coef: 0.4444 - precision: 0.9905 - sensitivity: 0.9829 - specificity: 0.9967 - val_loss: 0.0405 - val_accuracy: 0.9868 - val_mean_io_u: 0.4064 - val_dice_coef: 0.4459 - val_precision: 0.9917 - val_sensitivity: 0.9812 - val_specificity: 0.9971 - lr: 2.0000e-04
# Epoch 11/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9875 - mean_io_u: 0.4148 - dice_coef: 0.4584 - precision: 0.9909 - sensitivity: 0.9838 - specificity: 0.9969
# Epoch 11: val_loss improved from 0.04050 to 0.03645, saving model to model_.11-0.036447.m5
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0369 - accuracy: 0.9875 - mean_io_u: 0.4148 - dice_coef: 0.4584 - precision: 0.9909 - sensitivity: 0.9838 - specificity: 0.9969 - val_loss: 0.0364 - val_accuracy: 0.9879 - val_mean_io_u: 0.3868 - val_dice_coef: 0.4657 - val_precision: 0.9914 - val_sensitivity: 0.9837 - val_specificity: 0.9970 - lr: 2.0000e-04
# Epoch 12/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9881 - mean_io_u: 0.4128 - dice_coef: 0.4732 - precision: 0.9913 - sensitivity: 0.9845 - specificity: 0.9970
# Epoch 12: val_loss did not improve from 0.03645
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0346 - accuracy: 0.9881 - mean_io_u: 0.4128 - dice_coef: 0.4732 - precision: 0.9913 - sensitivity: 0.9845 - specificity: 0.9970 - val_loss: 0.0366 - val_accuracy: 0.9873 - val_mean_io_u: 0.4099 - val_dice_coef: 0.4720 - val_precision: 0.9904 - val_sensitivity: 0.9836 - val_specificity: 0.9967 - lr: 2.0000e-04
# Epoch 13/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9886 - mean_io_u: 0.4358 - dice_coef: 0.4874 - precision: 0.9914 - sensitivity: 0.9854 - specificity: 0.9971
# Epoch 13: val_loss improved from 0.03645 to 0.03369, saving model to model_.13-0.033692.m5
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0325 - accuracy: 0.9886 - mean_io_u: 0.4358 - dice_coef: 0.4874 - precision: 0.9914 - sensitivity: 0.9854 - specificity: 0.9971 - val_loss: 0.0337 - val_accuracy: 0.9882 - val_mean_io_u: 0.4507 - val_dice_coef: 0.4831 - val_precision: 0.9908 - val_sensitivity: 0.9852 - val_specificity: 0.9969 - lr: 2.0000e-04
# Epoch 14/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9889 - mean_io_u: 0.6049 - dice_coef: 0.4951 - precision: 0.9916 - sensitivity: 0.9858 - specificity: 0.9971
# Epoch 14: val_loss improved from 0.03369 to 0.03282, saving model to model_.14-0.032823.m5
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0311 - accuracy: 0.9889 - mean_io_u: 0.6049 - dice_coef: 0.4951 - precision: 0.9916 - sensitivity: 0.9858 - specificity: 0.9971 - val_loss: 0.0328 - val_accuracy: 0.9889 - val_mean_io_u: 0.7094 - val_dice_coef: 0.4979 - val_precision: 0.9919 - val_sensitivity: 0.9854 - val_specificity: 0.9972 - lr: 2.0000e-04
# Epoch 15/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9893 - mean_io_u: 0.6411 - dice_coef: 0.5052 - precision: 0.9918 - sensitivity: 0.9863 - specificity: 0.9972
# Epoch 15: val_loss improved from 0.03282 to 0.03149, saving model to model_.15-0.031491.m5
# 250/250 [==============================] - 121s 483ms/step - loss: 0.0299 - accuracy: 0.9893 - mean_io_u: 0.6411 - dice_coef: 0.5052 - precision: 0.9918 - sensitivity: 0.9863 - specificity: 0.9972 - val_loss: 0.0315 - val_accuracy: 0.9891 - val_mean_io_u: 0.4362 - val_dice_coef: 0.4932 - val_precision: 0.9917 - val_sensitivity: 0.9858 - val_specificity: 0.9972 - lr: 2.0000e-04
# Epoch 16/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9896 - mean_io_u: 0.5959 - dice_coef: 0.5139 - precision: 0.9920 - sensitivity: 0.9866 - specificity: 0.9973
# Epoch 16: val_loss did not improve from 0.03149
# 250/250 [==============================] - 121s 485ms/step - loss: 0.0290 - accuracy: 0.9896 - mean_io_u: 0.5959 - dice_coef: 0.5139 - precision: 0.9920 - sensitivity: 0.9866 - specificity: 0.9973 - val_loss: 0.0338 - val_accuracy: 0.9887 - val_mean_io_u: 0.7098 - val_dice_coef: 0.4918 - val_precision: 0.9917 - val_sensitivity: 0.9849 - val_specificity: 0.9971 - lr: 2.0000e-04
# Epoch 17/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9900 - mean_io_u: 0.6384 - dice_coef: 0.5238 - precision: 0.9921 - sensitivity: 0.9871 - specificity: 0.9973
# Epoch 17: val_loss improved from 0.03149 to 0.02971, saving model to model_.17-0.029715.m5
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0276 - accuracy: 0.9900 - mean_io_u: 0.6384 - dice_coef: 0.5238 - precision: 0.9921 - sensitivity: 0.9871 - specificity: 0.9973 - val_loss: 0.0297 - val_accuracy: 0.9897 - val_mean_io_u: 0.5427 - val_dice_coef: 0.5108 - val_precision: 0.9918 - val_sensitivity: 0.9870 - val_specificity: 0.9972 - lr: 2.0000e-04
# Epoch 18/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9903 - mean_io_u: 0.6207 - dice_coef: 0.5300 - precision: 0.9922 - sensitivity: 0.9875 - specificity: 0.9973
# Epoch 18: val_loss improved from 0.02971 to 0.02937, saving model to model_.18-0.029368.m5
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0269 - accuracy: 0.9903 - mean_io_u: 0.6207 - dice_coef: 0.5300 - precision: 0.9922 - sensitivity: 0.9875 - specificity: 0.9973 - val_loss: 0.0294 - val_accuracy: 0.9899 - val_mean_io_u: 0.5296 - val_dice_coef: 0.5146 - val_precision: 0.9927 - val_sensitivity: 0.9862 - val_specificity: 0.9975 - lr: 2.0000e-04
# Epoch 19/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9903 - mean_io_u: 0.5536 - dice_coef: 0.5294 - precision: 0.9922 - sensitivity: 0.9875 - specificity: 0.9973
# Epoch 19: val_loss improved from 0.02937 to 0.02803, saving model to model_.19-0.028034.m5
# 250/250 [==============================] - 122s 486ms/step - loss: 0.0273 - accuracy: 0.9903 - mean_io_u: 0.5536 - dice_coef: 0.5294 - precision: 0.9922 - sensitivity: 0.9875 - specificity: 0.9973 - val_loss: 0.0280 - val_accuracy: 0.9900 - val_mean_io_u: 0.4999 - val_dice_coef: 0.5338 - val_precision: 0.9916 - val_sensitivity: 0.9874 - val_specificity: 0.9972 - lr: 2.0000e-04
# Epoch 20/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9908 - mean_io_u: 0.6296 - dice_coef: 0.5421 - precision: 0.9925 - sensitivity: 0.9881 - specificity: 0.9974
# Epoch 20: val_loss did not improve from 0.02803
# 250/250 [==============================] - 121s 485ms/step - loss: 0.0258 - accuracy: 0.9908 - mean_io_u: 0.6296 - dice_coef: 0.5421 - precision: 0.9925 - sensitivity: 0.9881 - specificity: 0.9974 - val_loss: 0.0281 - val_accuracy: 0.9903 - val_mean_io_u: 0.4633 - val_dice_coef: 0.5480 - val_precision: 0.9915 - val_sensitivity: 0.9882 - val_specificity: 0.9971 - lr: 2.0000e-04
# Epoch 21/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9912 - mean_io_u: 0.5566 - dice_coef: 0.5510 - precision: 0.9925 - sensitivity: 0.9888 - specificity: 0.9975
# Epoch 21: val_loss improved from 0.02803 to 0.02653, saving model to model_.21-0.026529.m5
# 250/250 [==============================] - 121s 485ms/step - loss: 0.0247 - accuracy: 0.9912 - mean_io_u: 0.5566 - dice_coef: 0.5510 - precision: 0.9925 - sensitivity: 0.9888 - specificity: 0.9975 - val_loss: 0.0265 - val_accuracy: 0.9908 - val_mean_io_u: 0.4630 - val_dice_coef: 0.5477 - val_precision: 0.9922 - val_sensitivity: 0.9884 - val_specificity: 0.9974 - lr: 2.0000e-04
# Epoch 22/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9910 - mean_io_u: 0.5920 - dice_coef: 0.5545 - precision: 0.9924 - sensitivity: 0.9887 - specificity: 0.9974
# Epoch 22: val_loss improved from 0.02653 to 0.02560, saving model to model_.22-0.025604.m5
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0250 - accuracy: 0.9910 - mean_io_u: 0.5920 - dice_coef: 0.5545 - precision: 0.9924 - sensitivity: 0.9887 - specificity: 0.9974 - val_loss: 0.0256 - val_accuracy: 0.9910 - val_mean_io_u: 0.6707 - val_dice_coef: 0.5581 - val_precision: 0.9924 - val_sensitivity: 0.9887 - val_specificity: 0.9974 - lr: 2.0000e-04
# Epoch 23/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9917 - mean_io_u: 0.6806 - dice_coef: 0.5676 - precision: 0.9929 - sensitivity: 0.9894 - specificity: 0.9976
# Epoch 23: val_loss did not improve from 0.02560
# 250/250 [==============================] - 121s 485ms/step - loss: 0.0232 - accuracy: 0.9917 - mean_io_u: 0.6806 - dice_coef: 0.5676 - precision: 0.9929 - sensitivity: 0.9894 - specificity: 0.9976 - val_loss: 0.0268 - val_accuracy: 0.9909 - val_mean_io_u: 0.6665 - val_dice_coef: 0.5565 - val_precision: 0.9920 - val_sensitivity: 0.9887 - val_specificity: 0.9973 - lr: 2.0000e-04
# Epoch 24/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9918 - mean_io_u: 0.6373 - dice_coef: 0.5703 - precision: 0.9928 - sensitivity: 0.9896 - specificity: 0.9976
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 24: val_loss did not improve from 0.02560
# 250/250 [==============================] - 121s 483ms/step - loss: 0.0228 - accuracy: 0.9918 - mean_io_u: 0.6373 - dice_coef: 0.5703 - precision: 0.9928 - sensitivity: 0.9896 - specificity: 0.9976 - val_loss: 0.0258 - val_accuracy: 0.9912 - val_mean_io_u: 0.6361 - val_dice_coef: 0.5607 - val_precision: 0.9925 - val_sensitivity: 0.9889 - val_specificity: 0.9974 - lr: 2.0000e-04
# Epoch 25/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9925 - mean_io_u: 0.6784 - dice_coef: 0.5916 - precision: 0.9933 - sensitivity: 0.9904 - specificity: 0.9977
# Epoch 25: val_loss improved from 0.02560 to 0.02458, saving model to model_.25-0.024580.m5
# 250/250 [==============================] - 121s 482ms/step - loss: 0.0208 - accuracy: 0.9925 - mean_io_u: 0.6784 - dice_coef: 0.5916 - precision: 0.9933 - sensitivity: 0.9904 - specificity: 0.9977 - val_loss: 0.0246 - val_accuracy: 0.9916 - val_mean_io_u: 0.6931 - val_dice_coef: 0.5850 - val_precision: 0.9922 - val_sensitivity: 0.9899 - val_specificity: 0.9974 - lr: 4.0000e-05
# Epoch 26/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9927 - mean_io_u: 0.7279 - dice_coef: 0.5996 - precision: 0.9934 - sensitivity: 0.9908 - specificity: 0.9977
# Epoch 26: val_loss improved from 0.02458 to 0.02401, saving model to model_.26-0.024011.m5
# 250/250 [==============================] - 121s 485ms/step - loss: 0.0202 - accuracy: 0.9927 - mean_io_u: 0.7279 - dice_coef: 0.5996 - precision: 0.9934 - sensitivity: 0.9908 - specificity: 0.9977 - val_loss: 0.0240 - val_accuracy: 0.9918 - val_mean_io_u: 0.7538 - val_dice_coef: 0.5854 - val_precision: 0.9926 - val_sensitivity: 0.9899 - val_specificity: 0.9975 - lr: 4.0000e-05
# Epoch 27/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9928 - mean_io_u: 0.7496 - dice_coef: 0.6016 - precision: 0.9934 - sensitivity: 0.9909 - specificity: 0.9978
# Epoch 27: val_loss improved from 0.02401 to 0.02371, saving model to model_.27-0.023710.m5
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0199 - accuracy: 0.9928 - mean_io_u: 0.7496 - dice_coef: 0.6016 - precision: 0.9934 - sensitivity: 0.9909 - specificity: 0.9978 - val_loss: 0.0237 - val_accuracy: 0.9918 - val_mean_io_u: 0.7660 - val_dice_coef: 0.5887 - val_precision: 0.9924 - val_sensitivity: 0.9900 - val_specificity: 0.9974 - lr: 4.0000e-05
# Epoch 28/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9928 - mean_io_u: 0.7764 - dice_coef: 0.6058 - precision: 0.9934 - sensitivity: 0.9910 - specificity: 0.9978
# Epoch 28: val_loss did not improve from 0.02371
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0197 - accuracy: 0.9928 - mean_io_u: 0.7764 - dice_coef: 0.6058 - precision: 0.9934 - sensitivity: 0.9910 - specificity: 0.9978 - val_loss: 0.0250 - val_accuracy: 0.9917 - val_mean_io_u: 0.7959 - val_dice_coef: 0.5854 - val_precision: 0.9922 - val_sensitivity: 0.9901 - val_specificity: 0.9974 - lr: 4.0000e-05
# Epoch 29/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9930 - mean_io_u: 0.8014 - dice_coef: 0.6070 - precision: 0.9935 - sensitivity: 0.9911 - specificity: 0.9978
# Epoch 29: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 29: val_loss did not improve from 0.02371
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0195 - accuracy: 0.9930 - mean_io_u: 0.8014 - dice_coef: 0.6070 - precision: 0.9935 - sensitivity: 0.9911 - specificity: 0.9978 - val_loss: 0.0240 - val_accuracy: 0.9919 - val_mean_io_u: 0.8048 - val_dice_coef: 0.5932 - val_precision: 0.9925 - val_sensitivity: 0.9902 - val_specificity: 0.9975 - lr: 4.0000e-05
# Epoch 30/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9932 - mean_io_u: 0.8105 - dice_coef: 0.6127 - precision: 0.9937 - sensitivity: 0.9914 - specificity: 0.9978
# Epoch 30: val_loss improved from 0.02371 to 0.02371, saving model to model_.30-0.023710.m5
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0189 - accuracy: 0.9932 - mean_io_u: 0.8105 - dice_coef: 0.6127 - precision: 0.9937 - sensitivity: 0.9914 - specificity: 0.9978 - val_loss: 0.0237 - val_accuracy: 0.9919 - val_mean_io_u: 0.8043 - val_dice_coef: 0.5950 - val_precision: 0.9925 - val_sensitivity: 0.9902 - val_specificity: 0.9975 - lr: 8.0000e-06
# Epoch 31/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9932 - mean_io_u: 0.8114 - dice_coef: 0.6143 - precision: 0.9936 - sensitivity: 0.9914 - specificity: 0.9978
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 31: val_loss improved from 0.02371 to 0.02370, saving model to model_.31-0.023700.m5
# 250/250 [==============================] - 121s 483ms/step - loss: 0.0188 - accuracy: 0.9932 - mean_io_u: 0.8114 - dice_coef: 0.6143 - precision: 0.9936 - sensitivity: 0.9914 - specificity: 0.9978 - val_loss: 0.0237 - val_accuracy: 0.9919 - val_mean_io_u: 0.8097 - val_dice_coef: 0.5945 - val_precision: 0.9925 - val_sensitivity: 0.9902 - val_specificity: 0.9975 - lr: 8.0000e-06
# Epoch 32/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9933 - mean_io_u: 0.8153 - dice_coef: 0.6143 - precision: 0.9937 - sensitivity: 0.9915 - specificity: 0.9979
# Epoch 32: val_loss did not improve from 0.02370
# 250/250 [==============================] - 121s 483ms/step - loss: 0.0186 - accuracy: 0.9933 - mean_io_u: 0.8153 - dice_coef: 0.6143 - precision: 0.9937 - sensitivity: 0.9915 - specificity: 0.9979 - val_loss: 0.0237 - val_accuracy: 0.9919 - val_mean_io_u: 0.8115 - val_dice_coef: 0.5952 - val_precision: 0.9925 - val_sensitivity: 0.9903 - val_specificity: 0.9975 - lr: 1.6000e-06
# Epoch 33/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9933 - mean_io_u: 0.8164 - dice_coef: 0.6148 - precision: 0.9937 - sensitivity: 0.9915 - specificity: 0.9979
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 33: val_loss did not improve from 0.02370
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0186 - accuracy: 0.9933 - mean_io_u: 0.8164 - dice_coef: 0.6148 - precision: 0.9937 - sensitivity: 0.9915 - specificity: 0.9979 - val_loss: 0.0238 - val_accuracy: 0.9919 - val_mean_io_u: 0.8134 - val_dice_coef: 0.5956 - val_precision: 0.9925 - val_sensitivity: 0.9903 - val_specificity: 0.9975 - lr: 1.6000e-06
# Epoch 34/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9933 - mean_io_u: 0.8178 - dice_coef: 0.6158 - precision: 0.9937 - sensitivity: 0.9915 - specificity: 0.9979
# Epoch 34: val_loss did not improve from 0.02370
# 250/250 [==============================] - 122s 486ms/step - loss: 0.0186 - accuracy: 0.9933 - mean_io_u: 0.8178 - dice_coef: 0.6158 - precision: 0.9937 - sensitivity: 0.9915 - specificity: 0.9979 - val_loss: 0.0237 - val_accuracy: 0.9919 - val_mean_io_u: 0.8133 - val_dice_coef: 0.5957 - val_precision: 0.9925 - val_sensitivity: 0.9903 - val_specificity: 0.9975 - lr: 1.0000e-06
# Epoch 35/35
# 250/250 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9933 - mean_io_u: 0.8177 - dice_coef: 0.6157 - precision: 0.9937 - sensitivity: 0.9915 - specificity: 0.9979
# Epoch 35: val_loss did not improve from 0.02370
# 250/250 [==============================] - 121s 484ms/step - loss: 0.0186 - accuracy: 0.9933 - mean_io_u: 0.8177 - dice_coef: 0.6157 - precision: 0.9937 - sensitivity: 0.9915 - specificity: 0.9979 - val_loss: 0.0237 - val_accuracy: 0.9919 - val_mean_io_u: 0.8133 - val_dice_coef: 0.5957 - val_precision: 0.9925 - val_sensitivity: 0.9903 - val_specificity: 0.9975 - lr: 1.0000e-06

# %% [markdown]
# **Step 11: Metrics analysis**

# %%
# Read the CSVlogger file that contains all our metrics (accuracy, loss, dice_coef, ...) of our training
history = pd.read_csv('training.log', sep=',', engine='python')

# Plot training and validation metrics
fig, axs = plt.subplots(1, 4, figsize=(16, 8))

axs[0].plot(history['epoch'], history['accuracy'], 'b', label='Training Accuracy')
axs[0].plot(history['epoch'], history['val_accuracy'], 'r', label='Validation Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend()

axs[1].plot(history['epoch'], history['loss'], 'b', label='Training Loss')
axs[1].plot(history['epoch'], history['val_loss'], 'r', label='Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
axs[1].legend()

axs[2].plot(history['epoch'], history['dice_coef'], 'b', label='Training dice coef')
axs[2].plot(history['epoch'], history['val_dice_coef'], 'r', label='Validation dice coef')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Dice Coefficient')
axs[2].legend()

axs[3].plot(history['epoch'], history['mean_io_u'], 'b', label='Training mean IOU')
axs[3].plot(history['epoch'], history['val_mean_io_u'], 'r', label='Validation mean IOU')
axs[3].set_xlabel('Epoch')
axs[3].set_ylabel('Mean IOU')
axs[3].legend()

# Add space between subplots
plt.subplots_adjust(wspace=0.4)

plt.show()

# %% [markdown]
# **Step 12: Tumor Segmentation Predictions**

# %%
def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1ce_path = sample_path + '_t1ce.nii'
    flair_path = sample_path + '_flair.nii'
    #t1_path = sample_path + '_t1.nii'
    #t2_path = sample_path + '_t2.nii'

    # Extract the data from these paths
    t1ce = nib.load(t1ce_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()

    # Create an empty array
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    # Send our images to the CNN model and return predicted segmentation
    return model.predict(X/np.max(X), verbose=1)

# %%
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm):
    # Choose a random patient
    random_sample = random.choice(samples_list)

    # Get path of this patient
    random_sample_path = os.path.join(data_path, random_sample, random_sample)

    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)

    # Load patient's original segmentation (Ground truth)
    seg_path = random_sample_path + '_seg.nii'
    seg = nib.load(seg_path).get_fdata()

    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)

    # Differentiate segmentations by their labels
    all = predicted_seg[slice_to_plot,:,:,1:4] # Deletion of class 0 (Keep only Core + Edema + Enhancing classes)
    zero = predicted_seg[slice_to_plot,:,:,0] # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot,:,:,1] # Isolation of class 1, Core
    second = predicted_seg[slice_to_plot,:,:,2] # Isolation of class 2, Edema
    third = predicted_seg[slice_to_plot,:,:,3] # Isolation of class 3, Enhancing

    # Plot Original segmentation & predicted segmentation
    print("Patient number: ", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')

    # Layers 1, 2, 3
    axstest[1].imshow(all)
    axstest[1].set_title('Predicted Segmentation - all layers')

    # Layer 0
    axstest[2].imshow(zero)
    axstest[2].set_title('Predicted Segmentation - layer 0')

    # Layer 1
    axstest[3].imshow(first)
    axstest[3].set_title('Predicted Segmentation - layer 1')

    # Layer 2
    axstest[4].imshow(second)
    axstest[4].set_title('Predicted Segmentation - layer 2')

    # Layer 3
    axstest[5].imshow(third)
    axstest[5].set_title('Predicted Segmentation - layer 3')

    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.show()

# %%
show_predicted_segmentations(samples_test, 60, cmap, norm)
# Out:
# 2/2 [==============================] - 4s 11ms/step
# Patient number:  BraTS20_Training_109

# %%
show_predicted_segmentations(samples_test, 50, cmap, norm)
# Out:
# 2/2 [==============================] - 0s 70ms/step
# Patient number:  BraTS20_Training_183

# %%
def show_post_processed_segmentations(sample, slice_to_plot, cmap, norm):

    # Get path of this patient
    sample_path = os.path.join(data_path, sample, sample)

    # Predict patient's segmentation
    predicted_seg = predict_segmentation(sample_path)

    # Load patient's original segmentation (Ground truth)
    seg_path = sample_path + '_seg.nii'
    seg = nib.load(seg_path).get_fdata()

    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)

    # Fix 4 to 3 to have the same values as in the predicted segmentation, and then same colors
    seg[seg==4] = 3

    # Remove background layer (0) from original segmentation
    seg[seg==0] = np.nan

    # Post-processing
    # Get indexes for each class of the highest probability pixels. Array will then contain only [0 1 2 3] instead of probabilities
    my_pred = np.argmax(predicted_seg, axis=3)
    my_pred = my_pred[slice_to_plot, :, :]

    # Remove background layer (0) from post-processed predicted segmentation
    # To fix 0 to np.nan, we need to convert array as a float
    my_pred = my_pred.astype(float)
    my_pred[my_pred == 0] = np.nan

    # Remove background layer (0) from classical predicted segmentation
    all = predicted_seg[slice_to_plot,:,:,1:4]

    # Plot Original segmentation & predicted segmentation without processing & predicted segmentation
    print("Patient number: ", sample)
    fig, axstest = plt.subplots(1, 3, figsize=(15, 10))

    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')

    axstest[1].imshow(all)
    axstest[1].set_title('Prediction (w/o post processing (layer 1,2,3)')

    axstest[2].imshow(my_pred, cmap, norm)
    axstest[2].set_title('Prediction (w/ post processing (layer 1,2,3)')

    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.show()

# %%
show_post_processed_segmentations(sample = "BraTS20_Training_266", slice_to_plot=60, cmap=cmap, norm=norm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0cd6dc83084c> in <cell line: 1>()
# ----> 1 show_post_processed_segmentations(sample = "BraTS20_Training_266", slice_to_plot=60, cmap=cmap, norm=norm)
#
# NameError: name 'show_post_processed_segmentations' is not defined

# %%
show_post_processed_segmentations(sample = "BraTS20_Training_051", slice_to_plot=50, cmap=cmap, norm=norm)
# Out:
# 2/2 [==============================] - 0s 71ms/step
# Patient number:  BraTS20_Training_051

# %%
show_post_processed_segmentations(sample = "BraTS20_Training_266", slice_to_plot=63, cmap=cmap, norm=norm)
# Out:
# 2/2 [==============================] - 0s 72ms/step
# Patient number:  BraTS20_Training_266

# %% [markdown]
# **Step 12 - Model Evaluation**

# %%
# Evaluate the model on the test data

results = model.evaluate(test_generator, batch_size=100, callbacks= callbacks)

descriptions = ["Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision", "Sensitivity", "Specificity"]

# Combine results list and descriptions list
results_list = zip(results, descriptions)

# Display each metric with its description
print("\nModel evaluation on the test set:")
print("==================================")
for i, (metric, description) in enumerate(results_list):
    print(f"{description} : {round(metric, 4)}")
# Out:
# 45/45 [==============================] - 12s 266ms/step - loss: 0.0262 - accuracy: 0.9916 - mean_io_u: 0.8199 - dice_coef: 0.6071 - precision: 0.9921 - sensitivity: 0.9900 - specificity: 0.9973
#
# Model evaluation on the test set:
# ==================================
# Loss : 0.0262
# Accuracy : 0.9916
# MeanIOU : 0.8199
# Dice coefficient : 0.6071
# Precision : 0.9921
# Sensitivity : 0.99
# Specificity : 0.9973
